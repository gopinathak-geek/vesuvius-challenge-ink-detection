# %% [markdown]
# <a href="https://colab.research.google.com/github/gopinathak-geek/vesuvius-challenge-ink-detection/blob/main/data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -q kaggle

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle competitions download -c 'vesuvius-challenge-ink-detection'
# Out:
# ...
# 100% 20.6G/20.6G [01:46<00:00, 191MB/s]
# 100% 20.6G/20.6G [01:46<00:00, 208MB/s]

# %%
! mkdir data

# %%
# !unzip "vesuvius-challenge-ink-detection.zip" -d "data"
# Out:
# Archive:  vesuvius-challenge-ink-detection.zip
#   inflating: data/sample_submission.csv
#   inflating: data/test/a/mask.png
#   inflating: data/test/a/surface_volume/00.tif
#   inflating: data/test/a/surface_volume/01.tif
#   inflating: data/test/a/surface_volume/02.tif
#   inflating: data/test/a/surface_volume/03.tif
#   inflating: data/test/a/surface_volume/04.tif
#   inflating: data/test/a/surface_volume/05.tif
#   inflating: data/test/a/surface_volume/06.tif
#   inflating: data/test/a/surface_volume/07.tif
#   inflating: data/test/a/surface_volume/08.tif
#   inflating: data/test/a/surface_volume/09.tif
#   inflating: data/test/a/surface_volume/10.tif
#   inflating: data/test/a/surface_volume/11.tif
#   inflating: data/test/a/surface_volume/12.tif
#   inflating: data/test/a/surface_volume/13.tif
#   inflating: data/test/a/surface_volume/14.tif
#   inflating: data/test/a/surface_volume/15.tif
#   inflating: data/test/a/surface_volume/16.tif
# ...
